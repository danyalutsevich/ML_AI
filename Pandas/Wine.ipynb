# %%
import numpy as np
import pandas as pd

# %%
wine = pd.read_csv("../data/winequality-white.csv",delimiter=";")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine_modified = wine.drop([wine.columns[0],wine.columns[-1],wine.columns[-2],wine.columns[-3],wine.columns[4],wine.columns[5]], axis=1)
wine_modified.tail(15)
# Out:
#       volatile acidity  citric acid  residual sugar  total sulfur dioxide  \
# 4883             0.470         0.17            1.90                 148.0
# 4884             0.330         0.38            8.30                 174.0
# 4885             0.340         0.40            8.10                 170.0
# 4886             0.210         0.28            5.70                 121.0
# 4887             0.410         0.22            1.90                  56.0
# 4888             0.220         0.36            1.20                 127.0
# 4889             0.235         0.27           11.75                 118.0
# 4890             0.340         0.29            2.20                 100.0
# 4891             0.210         0.32            0.90                 121.0
# 4892             0.230         0.38            1.30                 112.0
# 4893             0.210         0.29            1.60                  92.0
# 4894             0.320         0.36            8.00                 168.0
# ...

# %%
M1 = 19
M2 = 47
N1 = 3
N2 = 110

# %%
critic_score = np.random.randint(M1, M2, size=len(wine_modified))

# %%
wine_modified["citric score"] = critic_score

# %%
wine_modified
# Out:
#       volatile acidity  citric acid  residual sugar  total sulfur dioxide  \
# 0                 0.27         0.36            20.7                 170.0
# 1                 0.30         0.34             1.6                 132.0
# 2                 0.28         0.40             6.9                  97.0
# 3                 0.23         0.32             8.5                 186.0
# 4                 0.23         0.32             8.5                 186.0
# ...                ...          ...             ...                   ...
# 4893              0.21         0.29             1.6                  92.0
# 4894              0.32         0.36             8.0                 168.0
# 4895              0.24         0.19             1.2                 111.0
# 4896              0.29         0.30             1.1                 110.0
# 4897              0.21         0.38             0.8                  98.0
#
#       density    pH  citric score
# 0     1.00100  3.00            30
# ...

# %% [markdown]
# ### У меня вместо столбца magnesium будет total sulfur dioxide

# %%
wine_modified.iloc[:N1]=0
wine_modified
# Out:
#       volatile acidity  citric acid  residual sugar  total sulfur dioxide  \
# 0                 0.00         0.00             0.0                   0.0
# 1                 0.00         0.00             0.0                   0.0
# 2                 0.00         0.00             0.0                   0.0
# 3                 0.23         0.32             8.5                 555.0
# 4                 0.23         0.32             8.5                 186.0
# ...                ...          ...             ...                   ...
# 4893              0.21         0.29             1.6                  92.0
# 4894              0.32         0.36             8.0                 168.0
# 4895              0.24         0.19             1.2                 111.0
# 4896              0.29         0.30             1.1                 110.0
# 4897              0.21         0.38             0.8                  98.0
#
#       density    pH  citric score
# 0     0.00000  0.00             0
# ...

# %%
# wine_modified.loc[N1,:]=555
wine_modified["total sulfur dioxide"].loc[N1]= 555
wine_modified["total sulfur dioxide"].loc[N2]= 555
# Out:
# C:\Users\luche\AppData\Local\Temp\ipykernel_6768\2448095152.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_modified["total sulfur dioxide"].loc[N1]= 555
# C:\Users\luche\AppData\Local\Temp\ipykernel_6768\2448095152.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_modified["total sulfur dioxide"].loc[N2]= 555

# %% [markdown]
# #### вместо alcalinity of ash и proanthocyanins будет density и citric acid

# %%
wine_modified.loc[:,"density":"citric acid":-1]
# Out:
#       density  total sulfur dioxide  residual sugar  citric acid
# 0     0.00000                   0.0             0.0         0.00
# 1     0.00000                   0.0             0.0         0.00
# 2     0.00000                   0.0             0.0         0.00
# 3     0.99560                 555.0             8.5         0.32
# 4     0.99560                 186.0             8.5         0.32
# ...       ...                   ...             ...          ...
# 4893  0.99114                  92.0             1.6         0.29
# 4894  0.99490                 168.0             8.0         0.36
# 4895  0.99254                 111.0             1.2         0.19
# 4896  0.98869                 110.0             1.1         0.30
# 4897  0.98941                  98.0             0.8         0.38
#
# [4898 rows x 4 columns]

# %%
a = lambda col: wine_modified[col] * M1
a("pH")
# Out:
# 0        0.00
# 1        0.00
# 2        0.00
# 3       60.61
# 4       60.61
#         ...
# 4893    62.13
# 4894    59.85
# 4895    56.81
# 4896    63.46
# 4897    61.94
# Name: pH, Length: 4898, dtype: float64

# %%
wine_modified.assign(pH= a("pH"))
wine_modified
# Out:
#       volatile acidity  citric acid  residual sugar  total sulfur dioxide  \
# 0                 0.00         0.00             0.0                   0.0
# 1                 0.00         0.00             0.0                   0.0
# 2                 0.00         0.00             0.0                   0.0
# 3                 0.23         0.32             8.5                 555.0
# 4                 0.23         0.32             8.5                 186.0
# ...                ...          ...             ...                   ...
# 4893              0.21         0.29             1.6                  92.0
# 4894              0.32         0.36             8.0                 168.0
# 4895              0.24         0.19             1.2                 111.0
# 4896              0.29         0.30             1.1                 110.0
# 4897              0.21         0.38             0.8                  98.0
#
#       density    pH  citric score
# 0     0.00000  0.00             0
# ...
