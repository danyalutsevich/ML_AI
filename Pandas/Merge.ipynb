# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({"employee":["Bob","Jake","Lisa","Sue"],
"group":["Accounting","Engeneering","Engeneering","HR"]
})

df2 = pd.DataFrame({"employee":["Lisa","Bob","Jake","Sue"],
"hire_date":[2004,2008,2012,2014]
})

# %%
df3 = pd.merge(df1,df2)
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engeneering       2012
# 2     Lisa  Engeneering       2004
# 3      Sue           HR       2014

# %%
df4 = pd.DataFrame({
    "group":["Accounting","Engeneering","HR"],
    "supervisor":["Carly","Guido","Steve"]
})
df4
# Out:
#          group supervisor
# 0   Accounting      Carly
# 1  Engeneering      Guido
# 2           HR      Steve

# %%
pd.merge(df3,df4)
# Out:
#   employee        group  hire_date supervisor
# 0      Bob   Accounting       2008      Carly
# 1     Jake  Engeneering       2012      Guido
# 2     Lisa  Engeneering       2004      Guido
# 3      Sue           HR       2014      Steve

# %%
df5 = pd.DataFrame({
    "group":["Accounting","Accounting","Engeneering","Engeneering","HR","HR"],
    "skills":["math","spreadsheets","coding","linux","spreadsheets","organization"]
})
df5
# Out:
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engeneering        coding
# 3  Engeneering         linux
# 4           HR  spreadsheets
# 5           HR  organization

# %%
pd.merge(df1,df5)
# Out:
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engeneering        coding
# 3     Jake  Engeneering         linux
# 4     Lisa  Engeneering        coding
# 5     Lisa  Engeneering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR  organization

# %%
df2_1 = pd.DataFrame({"employee":["Lisa","Bob","Jake","Sue"],
"group":[2004,2008,2012,2014],
"hire_date":[2004,2008,2012,2014],
})
df3_1 = pd.merge(df1,df2_1,on="employee")
df3_1
# Out:
#   employee      group_x  group_y  hire_date
# 0      Bob   Accounting     2008       2008
# 1     Jake  Engeneering     2012       2012
# 2     Lisa  Engeneering     2004       2004
# 3      Sue           HR     2014       2014

# %%
df2_2 = pd.DataFrame({"employee":["Jake","Sue"],
"hire_date":[2004,2008],
})

# %%
pd.merge(df1,df2_2,on="employee")
# Out:
#   employee        group  hire_date
# 0     Jake  Engeneering       2004
# 1      Sue           HR       2008

# %%
df_a2011 = pd.read_csv("../data/americas_2011.csv")
df_a2012 = pd.read_csv("../data/americas_2012.csv")
df_a2010 = pd.read_csv("../data/north_america_2000_2010.csv")

df_sa = pd.read_csv("../data/south_america_2000_2010.csv")
df_na = pd.read_csv("../data/north_america_2000_2010.csv")

df_asia = pd.read_csv("../data/asia_2000_2015.csv")

# %%
df_a = df_a2010.append(df_sa)
df_a = pd.merge(df_a,df_a2011)
df_a =  pd.merge(df_a,df_a2012)
df_a
# Out:
# C:\Users\luche\AppData\Local\Temp\ipykernel_3772\1622058010.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_a = df_a2010.append(df_sa)
#   Country    2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# 0  Canada  1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# 1  Mexico  2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# 2     USA  1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
# 3   Chile  2263.0  2242.0  2250.0  2235.0  2232.0  2157  2165.0  2128.0  2095
#
#      2009    2010    2011    2012
# 0  1701.0  1703.0  1700.0  1713.0
# 1  2250.2  2242.4  2250.2  2225.8
# 2  1767.0  1778.0  1786.0  1789.0
# 3  2074.0  2069.6  2047.4  2024.0

# %%
df_asia
# Out:
#   Country  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  \
# 0  Israel  2017  1979  1993  1974  1942  1931  1919  1931  1929  1927  1918
# 1   Japan  1821  1809  1798  1799  1787  1775  1784  1785  1771  1714  1733
# 2   Korea  2512  2499  2464  2424  2392  2351  2346  2306  2246  2232  2187
# 3  Russia  1982  1980  1982  1993  1993  1989  1998  1999  1997  1974  1976
#
#    2011  2012  2013  2014  2015
# 0  1920  1910  1867  1853  1858
# 1  1728  1745  1734  1729  1719
# 2  2090  2163  2079  2124  2113
# 3  1979  1982  1980  1985  1978

# %%
df_population = pd.DataFrame({
    "Country":["Russia","Korea","Israel","India"],
    "Population":[144000000,765000000,8547000,1318700000],
})
df_area = pd.DataFrame({
    "Country":["Russia","Korea","Israel","India"],
    "Area":[17100000,100210,20770,3287000],
})

# %%
df_pop=pd.merge(df_population,df_area)

df_asia=pd.merge(df_area,df_asia,on=["Country"])
pd.merge(df_asia,df_pop,on=["Country","Area"])
# Out:
#   Country      Area  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# 0  Russia  17100000  1982  1980  1982  1993  1993  1989  1998  1999  1997
# 1   Korea    100210  2512  2499  2464  2424  2392  2351  2346  2306  2246
# 2  Israel     20770  2017  1979  1993  1974  1942  1931  1919  1931  1929
#
#    2009  2010  2011  2012  2013  2014  2015  Population
# 0  1974  1976  1979  1982  1980  1985  1978   144000000
# 1  2232  2187  2090  2163  2079  2124  2113   765000000
# 2  1927  1918  1920  1910  1867  1853  1858     8547000
